# %%
#Tuples are similiar to lists, They however have one key difference which is immutability. 
#Elements inside a tuple cannot be changed 
t=(1,2,3)

# %%
my_list =[1,2,3]

# %%
type(t)
# Out:
# tuple

# %%
type(my_list)
# Out:
# list

# %%
len(t)
# Out:
# 3

# %%
len(my_list)
# Out:
# 3

# %%
#you can also mix object types inside a tuple
t= (1, 'One')
print(t)
# Out:
# (1, 'One')

# %%
t[0]
# Out:
# 1

# %%
t[-1]
# Out:
# 'One'

# %%
t =('a','a','b')

# %%
#you can use the count function to count the number of times an element appears in a tuple
t.count('a')
# Out:
# 2

# %%
#The .undex function returns the index where the element first occured 
t.index('a')
# Out:
# 0

# %%
t
# Out:
# ('a', 'a', 'b')

# %%
my_list
# Out:
# [1, 2, 3]

# %%
my_list[0] = 'NEW'

# %%
my_list
# Out:
# ['NEW', 2, 3]

# %%
#test that tuples are imutability 
t[0] = 'new'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-f469ab99125e> in <module>
# ----> 1 t[0] = 'new'
#
# TypeError: 'tuple' object does not support item assignment
