# %%
mystring = 'Hello World'

# %%
mystring
# Out:
# 'Hello World'

# %%
mystring[0]
# Out:
# 'H'

# %%
mystring[8]
# Out:
# 'r'

# %%
mystring[9]
# Out:
# 'l'

# %%
mystring[-3]
# Out:
# 'r'

# %%
len(mystring)
# Out:
# 11

# %%
mystring[-1]
# Out:
# 'd'

# %%
mystring[-9]
#In Indexing, -1 is always the last letter fo the string
# Out:
# 'l'

# %%
alpha_string = 'abcdefghijk'

# %%
print(alpha_string)
# Out:
# abcdefghijk

# %%
#To grab all the letters staing at index 2:
alpha_string[2:]
# Out:
# 'cdefghijk'

# %%
#To grab up to a particular index:
alpha_string[:3]
#stop index goes up that index but does not include
# Out:
# 'abc'

# %%
#grab  chracters d up to f not including g
alpha_string[3:6]
# Out:
# 'def'

# %%
#To grab only b and c
alpha_string[1:3]
# Out:
# 'bc'

# %%
#You can use two : to grab everythinng in the string
alpha_string[::]
# Out:
# 'abcdefghijk'

# %%
#Most likely used in step size notation. ex:
alpha_string[::2]
# Out:
# 'acegik'

# %%
#example of using step size
alpha_string[2:7:2]
# Out:
# 'ceg'

# %%
#In Jupyter noyebook, I had to redefine alpha_string in the line below to print its contents 
alpha_string = 'abcdefghijk'

# %%
print(alpha_string)
# Out:
# abcdefghijk

# %%
#This is a method/trick that can be used to reverse a string instad of using a (for loop) 
alpha_string[::-1]
# Out:
# 'kjihgfedcba'
